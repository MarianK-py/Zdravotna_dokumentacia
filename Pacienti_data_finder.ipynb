# %%
import pandas as pd
import numpy as np
import re

# %%
pacienti = pd.read_excel("Antivirotika KIGM COVID-19.xlsx", sheet_name='Hárok1')
pacienti.set_index("Rodné číslo", inplace=True) 
pacienti["Olumiant"] = pacienti["Olumiant"].map({"ano":1, "áno":1, 0:0, 1:1})

# %% [markdown]
# Zoznamy a slovníky pre vyhľadávanie v texte

# %%
udaje = {"hypoxemia": ["Hypoxemia", "hypoxemia"], 
         "oxygenoterapia": ["Oxygenoterapia", "oxygenoterapia",
                            "HFNO", "high-flow", "high flow", "low-flow", "low flow",
                            "UPV", "umel.{1,5}pľúc.{1,5}venti.{8}", "CPAP",
                            "maska", "nosová kanyla", ".{10}kanyla"], 
         "smrť": ["smrť", "pitva"], "JIS": ["JIS", "jedno.{2,6}inten.{5,9}staro.{10}"]}

vys_vah = [["výška.{0,3}[0-9]+.{0,2}cm"], ["váha.{0,3}[0-9]+.{0,2}kg", "hmotnosť.{0,3}[0-9]+.{0,2}kg"],
           ["[0-9]+.{0,2}cm.{0,2}/.{0,2}[0-9]+.{0,2}kg"], ["[0-9]+.{0,2}cm,.{0,2}[0-9]+.{0,2}kg"], ["[0-9]+.{0,2}cm .{0,2}[0-9]+.{0,2}kg"],
           ["[0-9]+.{0,2}kg.{0,2}/.{0,2}[0-9]+.{0,2}cm"], ["[0-9]+.{0,2}kg,.{0,2}[0-9]+.{0,2}cm"], ["[0-9]+.{0,2}kg .{0,2}[0-9]+.{0,2}cm"]]

vys_vah_sep = [["", ["výška"]], ["", ["váha"]], 
               ["/", ["výška", "váha"]], [",", ["výška", "váha"]], ["cm", ["výška", "váha"]], 
               ["/", ["váha", "výška"]], [",", ["váha", "výška"]], ["kg", ["váha", "výška"]]]

vys_basic = ["[0-9]+.{0,2}cm"]

vah_basic = ["[0-9]+.{0,2}kg"]

lieky = {"Deaxmetazon": ["Dexametazon", "dexametazon"], "remdesivir": ["Remdesivir", "remdesivir"], "Olumiant": ["Olumiant", "olumiant"], 
         "favipiravir": ["Favipiravir", "favipiravir"], "ivermectin": ["Ivermectin", "ivermectin"], "colchicin": ["Colchicin", "colchicin"]}

saturacia = ["SpO2 pri prijati bez kyslik", "SpO2", "SatO2", "satO2", "Sat.O2", "sat.O2", 
             "SpO2 bez kyslík"]

vysledky = {"CRP": ["CRP"], "IL-6":["IL-6", "IL6"], "PCT":["PCT"], 
            "D vit": ["D vit", "vitamin D", "S_D3"], "glukóza na lačno": ["glukóza na lačno", "glukóza", "GLU"], 
            "kreatinin": ["kreatinin", "KREA"], "ALT": ["ALT"], "GMT": ["GMT"], "feritín": ["Feritín", "feritín", "FERR"], "TnT": ["TnT", "Troponín T hs"], 
            "Neu": ["Neu", "NEU#"], "Lymfo": ["Lymfo", "LYM#"], "Eo": ["Eo", "EO#"], 
            "Plt": ["Plt", "PLT"], "CD4 abs": ["CD4A"], "CD8 abs": ["CD8A"], "INR": ["INR"], "FBG": ["FBG"], "D-Dim": ["D-Dim", "DD"]}

choroby = {"Diabetes": ["Diabetes", "diabetes", "Cukrovka", "cukrovka"], 
           "AH": ["[\s,\n]AH[\s,\n]", "Hypertenzia", "hypertenzia", "artériová hypertenzia", "Artériová hypertenzia", "Arteriálna hypertenzia"], 
           "SZ": ["SZ(?!Č)", "[\s,\n]SZ[\s,\n]", "CHSZ", "ChSZ", "Srdcové zlyhanie", "srdcové zlyhanie", "Srdcové Zlyhanie"], 
           "IM": ["[\s,\n]IM[\s,\n]", "Infarkt", "infarkt", "infarkt myokardu", "Infarkt myokardu", "STEMI"], 
           "FP": ["[\s,\n]FP[\s,\n]", "fibrilácia", "Fibrilácia","fibrilácia predsiení", "Fibrilácia predsiení"], 
           "dialýza": ["dialýza", "Dialýza"], 
           "PAOO DK": ["PAOO DK", "PAO DK", "periférne artériové ochorenie dolných končatín", "Periférne artériové ochorenie dolných končatín", "Ateroskleróza", "ateroskleróza"], 
           "CHOCHP": ["CHOCHP", "ChoChP", "Chronická obštrukčná choroba pľúc"], 
           "Astma": ["Astma", "astma", "Asthma", "asthma"], 
           "NCMP": ["NCMP", "Cievna mozgová príhoda", "cievna mozgová príhoda", "Mozgová príhoda", "mozgová príhoda"], 
           "Demencia": ["Demencia", "demencia"], 
           "Sepsa pri hosp": ["Sepsa pri hosp", "Sepsa", "sepsa"], 
           "CDI pri hosp": ["CDI pri hosp", "CDI", "Kolitída", "kolitída", "difficile"]}

# %%
sars_names = ["SARS.{0,3}2?.{0,3}COV.{0,3}2?", "SARS.{0,3}2?.{0,3}CoV.{0,3}2?", "SARS.{0,3}2?.{0,3}Cov.{0,3}2?",
              "Sars.{0,3}2?.{0,3}CoV.{0,3}2?", "Sars.{0,3}2?.{0,3}Cov.{0,3}2?", "Sars.{0,3}2?.{0,3}cov.{0,3}2?", "sars.{0,3}cov.{0,3}2?",
              "COVID.{0,3}19", "Covid.{0,3}19", "covid.{0,3}19"]

protilatky = ["IgG", "IgM"]

poz = ["POZ", "Poz", "poz"]

neg = ["NEG", "Neg", "neg"]

treba_odstranit = ["SARS", "Sars", "sars", "SARS2", "Sars2", "sars2", "aSARS", 
                   "COV", "CoV", "Cov", "cov", "COV2", "CoV2", "Cov2", "cov2", "2",
                   "COVID", "Covid", "covid", "COVID19", "Covid19", "covid19", "19",
                   "", "lab.synlab", "00", "a", "v", "triede", "z", "i", "s", ".", "boli",
                   "slabo", "silno", "Rýchlotest", "rýchlotest", "rýchlotestom", "Anti", "anti"]

# %% [markdown]
# Funkcia ktorá v z dataframu spravý text a zavolá vyhľadávacie funkcie

# %%
def text_finder(pacient):
    hlavny_text = ""
    imuno_text = ""
    data = dict()
    data_temp = dict()
    problemy = []
    problemy_temp = []
    nenajdene = dict()
    
    start_imuno = False
    for index, value in pacient["Meno"].items():
        if(value == "Imunologické vyš.:"):
            start_imuno = True
        if(type(value) !=  float):
            if start_imuno:
                imuno_text += str(value)+"\n"
            else:
                hlavny_text += str(value)+"\n"
    
    #Osobne udaje:
    data_temp = osobne_udaje(pacient)
    data.update(data_temp)
    
    if ("chýba správa" in hlavny_text):
        print(pacient["Meno"][0])
        print("Chýba správa")
        print()
        return data, ["chýba správa"], []
    
    #Zakl. udaje:
    data_temp, problemy_temp = find_stav_pac(hlavny_text)
    data.update(data_temp)
    problemy += problemy_temp
    
    #Protilátky pri prijatí:
    data_temp, problemy_temp = find_protilatky(hlavny_text)
    data.update(data_temp)
    problemy += problemy_temp
    
    #Vyska/vaha:
    data_temp, problemy_temp = find_vys_vah(hlavny_text)
    data.update(data_temp)
    problemy += problemy_temp
    if (len(problemy_temp) == 0):
        data["BMI"] = data["váha"]/((data["výška"]/100)**2)
    
    #Saturacia:
    data_temp, problemy_temp = find_saturacia(hlavny_text)
    data.update(data_temp)
    problemy += problemy_temp 
        
    #Lieky:
    data_temp = find_lieky(hlavny_text)
    data.update(data_temp)
        
    #Vylsedky:  
    if (imuno_text != ""):
        data_temp, problemy_temp, nenajdene = find_vysledky(imuno_text, vysledky)
        if (len(nenajdene) != 0):
            data.update(data_temp)
            problemy += problemy_temp
            data_temp, problemy_temp, nenajdene = find_vysledky(hlavny_text, nenajdene)
    else:
        data_temp, problemy_temp, nenajdene = find_vysledky(hlavny_text, vysledky)
    data.update(data_temp)
    problemy += problemy_temp 
            
    #Choroby: 
    data_temp, problemy_temp = find_choroby(hlavny_text)
    data.update(data_temp)
    problemy += problemy_temp 
    
    print(pacient["Meno"][0])
    print("Problematické údaje:",problemy)
    print("Nenajdene vysl.:",list(nenajdene.keys()))
    print()
    
    return data, problemy, list(nenajdene.keys())

# %% [markdown]
# Funkcia hľadajúce udaje ako meno, RČ a dobu hospitalizácie

# %%
def osobne_udaje(pacient):
    data = dict()
    data["Meno"] = pacient[pacient.columns[0]][0].strip()
    data["Rodné číslo"] = pacient[pacient.columns[1]][0].strip()
    data["dátum prijatia"] = pd.Timestamp(pacient[pacient.columns[2]][0])
    
    if (type(pacient[pacient.columns[3]][0]) is str):
        if ("preklad" in pacient[pacient.columns[3]][0]):
            data["datum prepustenia"] = pd.Timestamp(pacient[pacient.columns[4]][0])  
        else:
            print("Problem (preklad)")
    else:
        data["datum prepustenia"] = pd.Timestamp(pacient[pacient.columns[3]][0])
        
        
    data["dlžka hosp."] = (data["datum prepustenia"] - data["dátum prijatia"]).days
    if (data["dlžka hosp."]<0 or data["dlžka hosp."]>100):
            print("Problem (číslo)")
    
    rok_nar = int(data["Rodné číslo"][0:2])
    mes_nar = int(data["Rodné číslo"][2:4])
    if (mes_nar > 50):
        mes_nar -= 50
    den_nar = int(data["Rodné číslo"][4:6])
    if (rok_nar < 22):
        if len(data["Rodné číslo"]) == 11:
            rok_nar += 100
    
    if (data["dátum prijatia"].month < mes_nar):
        data["vek"] = (data["dátum prijatia"].year - 1901) - rok_nar
    elif (data["dátum prijatia"].month > mes_nar):
        data["vek"] = (data["dátum prijatia"].year - 1900) - rok_nar
    else:
        if (data["dátum prijatia"].day < den_nar):
            data["vek"] = (data["dátum prijatia"].year - 1901) - rok_nar
        elif (data["dátum prijatia"].day >= den_nar):
            data["vek"] = (data["dátum prijatia"].year - 1900) - rok_nar
    
    return data

# %% [markdown]
# Hľadanie udajov o stave pacienta ako oxygenoterapia/JIS/smrť

# %%
def find_stav_pac(text):
    data = dict()
    problemy = []
    for i, udaj in udaje.items():
        out = []
        for j in udaj:
            out += re.findall(j,text)
        
        if (i == "JIS"):
            if (len(out) == 0):
                data[i] = 0
            else:
                data[i] = 1
        elif (i == "oxygenoterapia"):
            if (len(out) == 0):
                data[i] = "bez oxygenoterapie"
            else:
                if ("UPV" in out):
                    data[i] = "UPV"
                if (("HFNO" in out) or ("high-flow" in out) or ("high flow" in out)):
                    if ("UPV" in out):
                        data[i] = "HFNO/UPV"
                    else:
                        data[i] = "HFNO"
                if (data.get(i, "Problem") == "Problem"):
                    problemy.append(i)
        
    return data, problemy

# %% [markdown]
# Funkcia hľadajúca informácie o protilátkach

# %%
def find_protilatky(text):
    out = []
    problemy = []
    data = dict()
        
    for sars in sars_names:
        for vysl in (poz+neg):
            out += re.findall(sars+".{0,30}"+protilatky[0]+".{0,30}"+protilatky[1]+".{0,10}"+vysl,text)
            out += re.findall(sars+".{0,30}"+protilatky[1]+".{0,30}"+protilatky[0]+".{0,10}"+vysl,text)

        out += re.findall(sars+".{0,30}"+protilatky[1]+".{0,30}"+protilatky[0]+".{0,10}[0-9]+",text)
            
    if (out != []):
        for test in out:
            rozdel_test = re.split(",| |/|:|-|\(|\)|–",test)
            for i in rozdel_test.copy():
                if i in treba_odstranit:
                    rozdel_test.remove(i)
                        
            #print(rozdel_test)
            pocet_casti = len(rozdel_test)
                
            IgM, IgG = pozicie_testov(rozdel_test)
                
            counter = 0
            while (IgM != -1 and IgG != -1 and counter < 5):
                vysl = vysledky_testov(IgM, IgG, rozdel_test)
                data["IgM pri prijatí"] = data.get("IgM pri prijatí", 1) * vysl[0]
                data["IgG pri prijatí"] = data.get("IgG pri prijatí", 1) * vysl[1]
                rozdel_test = rozdel_test[(max(IgM, IgG))+1:]
                IgM, IgG = pozicie_testov(rozdel_test)
                counter += 1
    if ("IgG pri prijatí" not in data):
        problemy.append("IgG pri prijatí")
    if ("IgM pri prijatí" not in data):
        problemy.append("IgM pri prijatí")
        
    return data, problemy

# %% [markdown]
# Zisťovanie pozitivity/negativity

# %%
def poz_alebo_neg(vysl):
    pozit = []
    negat = []
    
    if vysl.isdigit():
        return 1
    
    for p in poz:
        pozit += re.findall(p, vysl)
    for n in neg:
        negat += re.findall(n, vysl)

    if (pozit == [] and negat == []) or (pozit != [] and negat != []):
        return -1
    elif pozit != []:
        return 1
    else:
        return 0

# %%
def pozicie_testov(rozdel_test):
    IgM = -1
    if ("IgM" in rozdel_test):
        IgM = rozdel_test.index("IgM")
    else:
        for j, cast in enumerate(rozdel_test):
            if "IgM" in cast:
                IgM = j
                
    IgG = -1
    if ("IgG" in rozdel_test):
        IgG = rozdel_test.index("IgG")
    else:
        for j, cast in enumerate(rozdel_test):
            if "IgG" in cast:
                IgG = j
                
    return [IgM, IgG]

# %% [markdown]
# Hľadanie výseldkov jendého protilátkového testu

# %%
def vysledky_testov(IgM, IgG, rozdel_test):
    pocet_casti = len(rozdel_test)
    vysl = [-1, -1]
    swap = False
    if (IgM > IgG):
        swap = True
        IgM, IgG = IgG, IgM
        
    if (IgM > 0):
        pozitM1 = poz_alebo_neg(rozdel_test[IgM-1])
    else:
        pozitM1 = -1
    if (IgM+1 < pocet_casti):
        pozitM2 = poz_alebo_neg(rozdel_test[IgM+1])
    else:
        pozitM2 = -1
                    
    if (IgG > 0):
        pozitG1 = poz_alebo_neg(rozdel_test[IgG-1])
    else:
        pozitG1 = -1
    if (IgG+1 < pocet_casti):
        pozitG2 = poz_alebo_neg(rozdel_test[IgG+1])
    else:
        pozitG2 = -1
                
    if (pozitM1 != -1):
        vysl[0] = pozitM1
    elif (pozitM2 != -1):
        vysl[0] = pozitM2
    elif (IgM+1 == IgG):
        if (pozitG2 != -1):
            vysl[0] = pozitG2

    if (pozitG2 != -1):
        vysl[1] = pozitG2
    elif (pozitG1 != -1):
        vysl[0] = pozitG1
    elif (IgM+1 == IgG):
        if (pozitM1 != -1):
            vysl[0] = pozitM1
    
    if swap:
        vysl.reverse()
        
    return vysl

# %% [markdown]
# Hľadanie výšky/váhy

# %%
def find_vys_vah(text):
    data = dict()
    problemy = []
    for i, hod in enumerate(vys_vah):
        out = []
        for j in hod:
            out += re.findall(j,text)
        if (out != []):
            for k in out:
                if vys_vah_sep[i][0] != "":
                    separated = k.split(vys_vah_sep[i][0])
                else:
                    separated = [k]
                for l, sep in enumerate(separated):
                    #print(vys_vah_sep[i][1][l],re.findall("[0-9]+",sep)[0])
                    data[vys_vah_sep[i][1][l]] = int(re.findall("[0-9]+",sep)[0])
    if ("výška" not in data):
        problemy.append("výška")
    if ("váha" not in data):
        problemy.append("váha")
        
    return data, problemy

# %% [markdown]
# Hľadanie saturácie

# %%
def find_saturacia(text):
    data = dict()
    problemy = []
    
    hodnoty_text = []
    hodnoty_cisla = []
    
    for sat in saturacia:
        hodnoty_text += re.findall(sat+".{1,3}[0-9]+",text)
        
    for hod in hodnoty_text:
        hod_cislo = int(re.findall("[0-9]+", hod)[-1])
        if (hod_cislo != 0):
            hodnoty_cisla.append(hod_cislo)
    
    if (len(hodnoty_cisla) != 0):
        data["SpO2 pri prijati bez kyslika"] = hodnoty_cisla[0]
    else:
        problemy += ["SpO2 pri prijati bez kyslika"]
        
    return data, problemy

# %% [markdown]
# Hľadanie liekov

# %%
def find_lieky(text):
    data = dict()
    for i, liek in lieky.items():
        out = []
        for j in liek:
            out += re.findall(j,text)
        if (len(out) == 0):
            #print(i,"= 0")
            data[i] = 0
        else:
            #print(i,"= 1")
            data[i] = 1
    return data

# %% [markdown]
# Hľadanie vysledkov krvných testov

# %%
def find_vysledky(text, vysledky_input):
    data = dict()
    problemy = []
    nenajdene = dict()
    for i, vysl in vysledky_input.items():
        hodnoty_text = []
        hodnoty_cisla = []
        
        for j in vysl:
            hodnoty_text += re.findall(j+".{2}[0-9,]+",text)
            
        for hod in hodnoty_text:
            hod_cislo = re.findall("[0-9,]+", hod)[-1].replace(",",".")
            if (hod_cislo != "."):
                if (hod_cislo[-1] == "."):
                    if (hod_cislo[0:-1].count(".") > 1):
                        problemy.append(i)
                    else:
                        hodnoty_cisla.append(float(hod_cislo[0:-1]))
                else:
                    if (hod_cislo.count(".") > 1):
                        problemy.append(i)
                    else:
                        hodnoty_cisla.append(float(hod_cislo))
                        
        if (len(hodnoty_cisla) == 0):
            nenajdene[i] = vysl
        elif (len(hodnoty_cisla) == 1):
            data[i] = hodnoty_cisla[0]
            #print(i,"=",hodnoty_cisla[0])
        else:
            prva_hod = hodnoty_cisla[0]
            for hod in hodnoty_cisla:
                if (prva_hod != hod):
                    if (i not in problemy):
                            problemy.append(i)
                else:
                    prva_hod = hod          
            data[i] = prva_hod
        
    return data, problemy, nenajdene

# %% [markdown]
# Hľadanie chorôb u pacienta

# %%
def find_choroby(text):
    data = dict()
    problemy = []
    for i, chor in choroby.items():
        out = []
        for j in chor:
            out += re.findall(j,text)
        if (len(out) == 0):
            #print(i,"= 0")
            data[i] = 0
        if (out != []):
            if (i == "CDI pri hosp"):
                vysl = kolitida_kontrola(text)
                if (vysl != -1):
                    data[i] = vysl
                else:
                    problemy.append("CDI pri hosp")
                #print(i, "problem")
            else:
                #print(i,"= 1",out)
                data[i] = 1
    return data, problemy

# %% [markdown]
# Špeciálna kontrola pri kolitide

# %%
def kolitida_kontrola(text):
    pozit = []
    negat = []
    for chor in choroby["CDI pri hosp"]:
        for p in poz:
            pozit += re.findall(chor+".{0,20}"+p, text)
        for n in neg:
            negat += re.findall(chor+".{0,20}"+n, text)
    
    if ((pozit == [] and negat == []) or (pozit != [] and negat != [])):
        return -1
    elif (pozit != []):
        return 1
    else:
        return 0

# %% [markdown]
# Pridávanie dových výsledkov do hlavného dataframu (vypisovanie problémov) (vstup čísla harkov)

# %%
def pridavanie_udajov(a, b):
    pacienti = pd.read_excel("Antivirotika KIGM COVID-19.xlsx", sheet_name='Hárok1')
    pacienti.set_index("Rodné číslo", inplace=True) 
    
    data = dict()
    problemy = []
    nenajdene = []
    with open("problemy.txt", "w", encoding='utf8') as problemy_dokument: 
        for p in range(a, b):
            print(f"Pacient z hárku {p}")
            try:
                pacient = pd.read_excel("Antivirotika KIGM COVID-19.xlsx", sheet_name=f"Hárok{p}")
            except:
                print(f"Problém s hárkom {p}")
                continue
            data, problemy, nenajdene = text_finder(pacient)
            problemy_dokument.write(f"Pacient z hárku {p}:\n")
            if ("chýba správa" in problemy):
                problemy_dokument.write(f"Chýba správa\n")
            else:
                problemy_dokument.write(f"Problemove udaje: {problemy}\n")
                problemy_dokument.write(f"Nenajdene vysledky: {nenajdene}\n")
            problemy_dokument.write("\n")
            if data != None:
                RC = data.pop("Rodné číslo")
                if (RC in pacienti.index):
                    #print("Problém s menom:",data["Meno"],pacienti.loc[RC,"Meno"])
                    #if data["Meno"] != pacienti.loc[RC,"Meno"]:
                    #    print("Problém s menom:",data["Meno"],pacienti.loc[RC,"Meno"])
                    for i, hod in data.items():
                        pacienti.loc[RC,i] = hod
                else:
                    pacienti.loc[RC] = data
    
    pacienti.reset_index(inplace=True)
    
    cols = list(pacienti.columns)
    a, b = cols.index('Meno'), cols.index('Rodné číslo')
    cols[b], cols[a] = cols[a], cols[b]
    pacienti = pacienti[cols]
    
    pacienti["dátum prijatia"] = pacienti["dátum prijatia"].dt.strftime('%d.%m.%Y')
    pacienti["datum prepustenia"] = pacienti["datum prepustenia"].dt.strftime('%d.%m.%Y')
    
    pacienti.to_excel(r'doplnene.xlsx', index = False)

# %%
pridavanie_udajov(2, 173)
# Out:
# Pacient z hárku 2
# Varga Štefan
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['PCT', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 3
# Velich Rudolf
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['D vit', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 4
# Sodoma Ján
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 5
# Šandor František
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'D-Dim']
#
# Pacient z hárku 6
# Federla Vladimír
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 7
# Bittnerová Eva
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 8
# Čihák Boris
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 9
# Moroczová Katarína
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 10
# Graus Vojtech
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 11
# Švec Ľuboš
# Problematické údaje: []
# Nenajdene vysl.: ['PCT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 12
# Dunaj Michal
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 13
# Forgáč Jozef
# Problematické údaje: []
# Nenajdene vysl.: ['IL-6', 'PCT', 'D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 14
# Lovás Jozef
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 15
# Adamovič Emil
# Chýba správa
#
# Pacient z hárku 16
# Problem (číslo)
# Dopirák Gabriel
# Chýba správa
#
# Pacient z hárku 17
# Mikulová Oľga
# Chýba správa
#
# Pacient z hárku 18
# Moťovská Oľga
# Chýba správa
#
# Pacient z hárku 19
# Paulenová Danka
# Chýba správa
#
# Pacient z hárku 20
# Zuštin František
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: []
#
# Pacient z hárku 21
# Husnaj Ján
# Chýba správa
#
# Pacient z hárku 22
# Galba Igor
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['D-Dim']
#
# Pacient z hárku 23
# Kopecký Rastislav
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 24
# Jesenská Želmíra
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'váha']
# Nenajdene vysl.: []
#
# Pacient z hárku 25
# Geleneky Juraj, ing.
# Chýba správa
#
# Pacient z hárku 26
# Horvát Ivo
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín']
#
# Pacient z hárku 27
# Kováčik Michal
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'D-Dim']
#
# Pacient z hárku 28
# Marochnič Miroslav
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín']
#
# Pacient z hárku 29
# Mozola Milan
# Problematické údaje: []
# Nenajdene vysl.: ['PCT', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 30
# Nemček Jozef
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 31
# Noskovičová Ružena
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 32
# Plachý Jaroslav
# Chýba správa
#
# Pacient z hárku 33
# Rímeš Jozef
# Chýba správa
#
# Pacient z hárku 34
# Jániová Margita
# Problematické údaje: []
# Nenajdene vysl.: []
#
# Pacient z hárku 35
# Šimoničová Alena
# Chýba správa
#
# Pacient z hárku 36
# Bordáč Marián
# Chýba správa
#
# Pacient z hárku 37
# Sninčáková Marta
# Chýba správa
#
# Pacient z hárku 38
# Blažek Radoslav
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['PCT', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 39
# Bortelová Anna
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 40
# Čech Pavel
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 41
# Čechová Daniela
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs', 'D-Dim']
#
# Pacient z hárku 42
# Grondžák Jozef
# Problematické údaje: ['oxygenoterapia', 'IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 43
# Horníčková Janka
# Problematické údaje: ['oxygenoterapia', 'IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 44
# Hoványeczová Eva
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 45
# Oboňová Martina
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 46
# Krištofičová Helena
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 47
# Huková Blažena
# Problematické údaje: ['oxygenoterapia', 'IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 48
# Jančová Rozália
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 49
# Javor Marián
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['PCT', 'feritín']
#
# Pacient z hárku 50
# Kollár Mojmír
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 51
# Matúšová Jarmila
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 52
# Mučajová Eva
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'TnT']
#
# Pacient z hárku 53
# Poláková Zlatuše
# Problematické údaje: ['oxygenoterapia', 'váha']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 54
# Rigová Katarína
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 55
# Varga Peter
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: []
#
# Pacient z hárku 56
# Vrábel Milan
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 57
# Bárdošová Andrea
# Problematické údaje: ['váha', 'TnT']
# Nenajdene vysl.: []
#
# Pacient z hárku 58
# Bajaníková Viola
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['D vit', 'feritín', 'TnT']
#
# Pacient z hárku 59
# Bátoryová Magda
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['D vit', 'ALT', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 60
# Beznák Matej
# Problematické údaje: []
# Nenajdene vysl.: []
#
# Pacient z hárku 61
# Biháry Andrej
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'TnT']
#
# Pacient z hárku 62
# Dlugošová Iveta
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 63
# Ďurovičová Mariana
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 64
# Chačatrian Anuš
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 65
# Barič Ján
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['GMT', 'TnT']
#
# Pacient z hárku 66
# Hutár Vladimír
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: []
#
# Pacient z hárku 67
# Juhos Augustín
# Problematické údaje: ['PCT']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 68
# Kolarczyková Darina
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 69
# Magyarics Štefan
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'GMT', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 70
# Mrvová Kristína
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 71
# Rehorčík Peter
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['TnT']
#
# Pacient z hárku 72
# Bartoš Ľudovít
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'GMT', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 73
# Filei Iván
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 74
# Heleši Vojtech
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 75
# Hrivíková Elena
# Problematické údaje: ['oxygenoterapia', 'výška', 'váha']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 76
# Hromkovič Miroslav
# Problematické údaje: ['oxygenoterapia', 'IgG pri prijatí', 'IgM pri prijatí', 'váha']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 77
# Husnajová Anastázia
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 78
# Kováč Marián
# Problematické údaje: ['oxygenoterapia', 'IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 79
# Kralovič Jozef
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 80
# Považanec Ivan
# Problematické údaje: ['oxygenoterapia', 'PCT', 'INR', 'FBG']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 81
# Rašla Peter
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 82
# Ružovič Miloš
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 83
# Totka Maroš
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 84
# Burianová Monika
# Problematické údaje: ['IL-6']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 85
# Ivanič Jozef
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 86
# Kormančík Jozef
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 87
# Kováčová Soňa
# Problematické údaje: ['oxygenoterapia', 'CRP', 'IL-6', 'TnT']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 88
# Lišková Magdaléna
# Problematické údaje: ['oxygenoterapia', 'IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 89
# Martonová Lucia
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 90
# Mihaleová Eva
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 91
# Mlejová Mária
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 92
# Mullerová Jarmila
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['PCT', 'D vit', 'glukóza na lačno', 'GMT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 93
# Oboňová Martina
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 94
# Ružičková Elena
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 95
# Trubačová Eva
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 96
# Zelina Ladislav
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Pacient z hárku 97
# Eckerová Klaudia
# Chýba správa
#
# Pacient z hárku 98
# Horňačková Zuzana
# Chýba správa
#
# Pacient z hárku 99
# Horváth Denis
# Chýba správa
#
# Pacient z hárku 100
# Hurbanič Ľudovít
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 101
# Kravec Martin
# Chýba správa
#
# Pacient z hárku 102
# Lovíšek Ján
# Chýba správa
#
# Pacient z hárku 103
# Murčo Jaroslav
# Chýba správa
#
# Pacient z hárku 104
# Plachý Jaroslav
# Chýba správa
#
# Pacient z hárku 105
# Rímeš Jozef
# Chýba správa
#
# Pacient z hárku 106
# Sninčáková Marta
# Chýba správa
#
# Pacient z hárku 107
# Horvát Ivo
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'CDI pri hosp']
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 108
# Javor Michal
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 109
# Jurčovičová Mária
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs', 'D-Dim']
#
# Pacient z hárku 110
# Katona Jozef
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs', 'D-Dim']
#
# Pacient z hárku 111
# Luknárová Monika
# Problematické údaje: []
# Nenajdene vysl.: ['PCT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 112
# Ružičková Miriam
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín']
#
# Pacient z hárku 113
# Barič Ján
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['GMT', 'TnT']
#
# Pacient z hárku 114
# Fellegiová Miloslava
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 115
# Holič Peter
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'PCT']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 116
# Jurica Ľubomír
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 117
# Yalamov Bisser
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 118
# Adámková Terézia
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 119
# Hanker Karol
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['PCT', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 120
# Hervayová Katarína
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 121
# Klčová Elena
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 122
# Korim Michal
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 123
# Kotek Jozef
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 124
# Krieglsteinová Mária
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 125
# Nagy Andrej
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'TnT']
#
# Pacient z hárku 126
# Neumann Vladimír
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: []
#
# Pacient z hárku 127
# Sajan Ján
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 128
# Sládečková Alžbeta
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 129
# Problém s hárkom 129
# Pacient z hárku 130
# Achbergerová Anna
# Problematické údaje: ['oxygenoterapia', 'váha']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 131
# Adamovičová Gabriela
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['PCT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 132
# Albertová Jana
# Problematické údaje: ['oxygenoterapia', 'IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 133
# Alena Jozef
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 134
# Aritonovič Ivan
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['CRP', 'IL-6', 'PCT', 'glukóza na lačno', 'kreatinin', 'ALT', 'GMT', 'TnT']
#
# Pacient z hárku 135
# Augustínová Jana
# Problematické údaje: ['výška', 'váha']
# Nenajdene vysl.: ['PCT', 'ALT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 136
# Baginová Kristína
# Problematické údaje: ['výška', 'váha']
# Nenajdene vysl.: ['D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 137
# Baluch Igor, Ing.
# Problematické údaje: ['oxygenoterapia', 'výška', 'váha', 'SpO2 pri prijati bez kyslika']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 138
# Banáš Jozef
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 139
# Bardún Štefan, Ing.
# Problematické údaje: ['oxygenoterapia', 'CRP']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 140
# Barna Miroslav, Mgr.
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha']
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 141
# Bathijarevic Igor
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: []
#
# Pacient z hárku 142
# Bednarovský František
# Problematické údaje: ['oxygenoterapia', 'výška', 'váha']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 143
# Belák Milan
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 144
# Benadiková Mária
# Problematické údaje: ['oxygenoterapia', 'výška', 'váha']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 145
# Benkovič Miroslav
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha', 'CDI pri hosp']
# Nenajdene vysl.: ['PCT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 146
# Beranová Slávka
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 147
# Bertovičová Žofia
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['TnT']
#
# Pacient z hárku 148
# Beseda Ivan, Ing.
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 149
# Bezdegová Zdenka
# Problematické údaje: ['oxygenoterapia', 'výška', 'váha']
# Nenajdene vysl.: ['PCT', 'GMT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 150
# Bielik Štefan
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['PCT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 151
# Bónová Inocencia
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 152
# Bors Jozef
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 153
# Božovič Budimír
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 154
# Braunsteiner Tomáš, MUDr.
# Problematické údaje: ['oxygenoterapia', 'IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha', 'SpO2 pri prijati bez kyslika']
# Nenajdene vysl.: ['D vit', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 155
# Briják Juraj
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 156
# Brunovská Jozefína
# Problematické údaje: ['oxygenoterapia', 'IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 157
# Bučič Dušan
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 158
# Cakl Juraj
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 159
# Chlapečka Tomáš
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'TnT']
#
# Pacient z hárku 160
# Chrobák Ondrej
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'TnT']
#
# Pacient z hárku 161
# Chrobáková Ivona
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'TnT']
#
# Pacient z hárku 162
# Chyba Dávid
# Problematické údaje: []
# Nenajdene vysl.: ['PCT', 'feritín', 'TnT']
#
# Pacient z hárku 163
# Cibula Ernest
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 164
# Cogan Ján
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 165
# Csonka Štefan
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Pacient z hárku 166
# Časnocha Jozef
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 167
# Čechová Alžbeta
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['PCT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 168
# Čemanová Mária
# Problematické údaje: ['výška', 'váha']
# Nenajdene vysl.: ['D vit', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 169
# Čepel Ľubomír
# Problematické údaje: ['oxygenoterapia', 'výška', 'váha']
# Nenajdene vysl.: ['PCT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 170
# Čerhitová Ľubica
# Problematické údaje: ['oxygenoterapia', 'SpO2 pri prijati bez kyslika']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Pacient z hárku 171
# Černá Jana
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha']
# Nenajdene vysl.: ['IL-6', 'PCT', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs', 'FBG', 'D-Dim']
#
# Pacient z hárku 172
# Černý Anton
# Problematické údaje: ['oxygenoterapia', 'IgG pri prijatí', 'IgM pri prijatí', 'SpO2 pri prijati bez kyslika', 'CDI pri hosp']
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
